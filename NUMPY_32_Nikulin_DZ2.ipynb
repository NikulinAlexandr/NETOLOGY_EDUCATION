# %%
#Задание 1

# %%
import pandas as pd
ratings = pd.read_csv('C:\\ml-25m\\ratings.csv')
movies = pd.read_csv('C:\\ml-25m\\movies.csv')#Можно это целиком засунуть в джоин, чтобы решение в 1 строчку получилось
ratings.query('rating == 5.0').groupby('movieId').count().nlargest(1, 'userId').join(movies)['title']
#Никак не пойму как избавиться от movieId
# Out:
# movieId
# 318    Swimming with Sharks (1995)
# Name: title, dtype: object

# %%
#Задание 2

# %%
power = pd.read_csv('C:\\Users\\alexn\\Documents\\Обучение\\DZ_7\\power.csv')
power.query("country in ['Lithuania','Latvia','Estonia'] & category in [4, 12, 22] & (year >= 2005 & year <= 2010) & quantity >= 0 ").sum()['quantity']
# Out:
# 6372.0

# %%
#Задание 3

# %%
#Не совсем понял само задание!
#Если просто импотрнуть некую таблицу - указываем порядковй номер в [], если несколько таблиц - в [] указывается диапазон,
#если все таблицы с ресурса - [] не нужны

#Если нужно сделать что то другое - разъясните, а то не понятно.
#Спасибо!


table_1 = pd.read_html('https://fortrader.org/quotes')[0]
list_of_tables = pd.read_html('https://fortrader.org/quotes')[:10]
all_tables = pd.read_html('https://fortrader.org/quotes')
#print(all_tables)
# Out:
# [                           Название   Цена  Изменение  Изменение(%)  Обновлено
# 0  EURRUB Курс евро к рублю сегодня  63.59     -27.66        -30.31        NaN
# 1       USDRUB Курс рубля к доллару  61.29     -24.26        -28.35        NaN,                               Название    Цена  Изменение  Изменение(%)  \
# 0       Нефть Brent Курс нефти сегодня  107.71      -8.35         -7.19
# 1          Нефть WTI Цены на нефть WTI  107.25      -2.99         -2.71
# 2  Природный газ Цена на природный газ    8.14       3.01         58.57
# 3                                 Кофе  216.25      -8.80         -3.91
# 4                             Кукуруза  775.60      24.20          3.22
# 5                                  Соя  418.00     -61.80        -12.88
# 6                               Хлопок  141.89      11.44          8.77
#
#    Обновлено
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# ...
